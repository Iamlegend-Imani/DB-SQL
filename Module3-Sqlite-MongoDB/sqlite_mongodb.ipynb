# %%
# imports.
import sqlite3
import pymongo

# %%
# get colab IP address.
! curl ifconfig.me
# Out:
# 35.201.245.105

# %%
# connect to the file.
sl_conn =sqlite3.connect('rpg_db.sqlite3')
# create the cursor.
sl_cur = sl_conn.cursor()

# %%
# select all the data for characters.
sl_cur.execute('SELECT * FROM charactercreator_character')
# create table of results of query.
sl_cc_table = sl_cur.fetchall()
# show the initial row in the table.
sl_cc_table[0]
# Out:
# (1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1)

# %%
# select the data for mage.
sl_cur.execute('SELECT * FROM charactercreator_mage')
sl_ccm_table = sl_cur.fetchall()
sl_ccm_table[0]
# Out:
# (69, 1, 100)

# %%
# select the data for thief.
sl_cur.execute('SELECT * FROM charactercreator_thief')
sl_cct_table = sl_cur.fetchall()
sl_cct_table[0]
# Out:
# (241, 0, 100)

# %%
# select the data for cleric.
sl_cur.execute('SELECT * FROM charactercreator_cleric')
sl_ccc_table = sl_cur.fetchall()
sl_ccc_table[0]
# Out:
# (166, 0, 100)

# %%
# select the data for fighter.
sl_cur.execute('SELECT * FROM charactercreator_fighter')
sl_ccf_table = sl_cur.fetchall()
sl_ccf_table[0]
# Out:
# (1, 0, 100)

# %%
# select the data for necromancer.
sl_cur.execute('SELECT * FROM charactercreator_necromancer')
sl_ccn_table = sl_cur.fetchall()
sl_ccn_table[0]
# Out:
# (292, 1)

# %%
# select the data for inventory.
sl_cur.execute('SELECT * FROM charactercreator_character_inventory')
sl_cci_table = sl_cur.fetchall()
sl_cci_table[0]
# Out:
# (1, 1, 58)

# %%
# select the data for armory item.
sl_cur.execute('SELECT * FROM armory_item')
sl_ai_table = sl_cur.fetchall()
sl_ai_table[0]
# Out:
# (1, 'Libero facere dolore, as', 0, 0)

# %%
# select the data for armory weapon.
sl_cur.execute('SELECT * FROM armory_weapon')
sl_aw_table = sl_cur.fetchall()
sl_aw_table[0]
# Out:
# (138, 0)

# %%
# connect to the pymongo database.
client = pymongo.MongoClient("mongodb://Admin:5y2b7bm6SWL5wynQ@cluster0-shard-00-00-cjusj.mongodb.net:27017,cluster0-shard-00-01-cjusj.mongodb.net:27017,cluster0-shard-00-02-cjusj.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
# label the new database.
db=client.RPGData_assignment
# set the RPGData to the new RPGData assignment.
rpg_data = db.rpg_data

# %%
# create loop to enter RPGData into the table.
for i in range(0, len(sl_cc_table)-1):
  rpg_data.insert_one({'id': i,
                       'char_id': sl_cc_table[i][0],
                       'name': sl_cc_table[i][1],
                       'level': sl_cc_table[i][2],
                       'exp': sl_cc_table[i][3],
                       'hp': sl_cc_table[i][4],
                       'strength': sl_cc_table[i][5],
                       'intelligence': sl_cc_table[i][6],
                       'dexterity': sl_cc_table[i][7],
                       'wisdom': sl_cc_table[i][8]
                        })

# %%
# create loop to enter RPGData into the table.
for i in range(0, len(sl_ccm_table)-1):
  rpg_data.insert_one({'id': i,
                       'char_ptr_id': sl_ccm_table[i][0],
                       'has_pet': sl_ccm_table[i][1],
                       'mana': sl_ccm_table[i][2]
                        })

# %%
# create loop to enter RPGData into the table.
for i in range(0, len(sl_cct_table)-1):
  rpg_data.insert_one({'id': i,
                       'char_ptrt_id': sl_cct_table[i][0],
                       'is_sneaking': sl_cct_table[i][1],
                       'energy': sl_cct_table[i][2]
                        })

# %%
# create loop to enter RPGData into the table.
for i in range(0, len(sl_ccc_table)-1):
  rpg_data.insert_one({'id': i,
                       'char_ptrc_id': sl_ccc_table[i][0],
                       'using_shield': sl_ccc_table[i][1],
                       'mana': sl_ccc_table[i][2]
                        })

# %%
# create loop to enter RPGData into the table.
for i in range(0, len(sl_ccf_table)-1):
  rpg_data.insert_one({'id': i,
                       'char_ptrf_id': sl_ccf_table[i][0],
                       'using_shield': sl_ccf_table[i][1],
                       'rage': sl_ccf_table[i][2]
                        })

# %%
# create loop to enter RPGData into the table.
for i in range(0, len(sl_ccn_table)-1):
  rpg_data.insert_one({'id': i,
                       'mage_ptr_id': sl_ccn_table[i][0],
                       'talisman_charged': sl_ccn_table[i][1]
                        })

# %%
# create loop to enter RPGData into the table.
for i in range(0, len(sl_cci_table)-1):
  rpg_data.insert_one({'id': i,
                       'char_ptri_id': sl_cci_table[i][0],
                       'char_id': sl_cci_table[i][1],
                       'item_id': sl_cci_table[i][2]
                        })

# %%
# create loop to enter RPGData into the table.
for i in range(0, len(sl_ai_table)-1):
  rpg_data.insert_one({'id': i,
                       'item_id': sl_ai_table[i][0],
                       'name': sl_ai_table[i][1],
                       'value': sl_ai_table[i][2],
                       'weight': sl_ai_table[i][3]
                        })

# %%
# create loop to enter RPGData into the table.
for i in range(0, len(sl_aw_table)-1):
  rpg_data.insert_one({'id': i,
                       'item_ptr_id': sl_aw_table[i][0],
                       'power': sl_aw_table[i][1]
                        })

# %%
# create the cursor.
cur = rpg_data.find()

# %%
# for loop to print all results generated.
for i in cur:
  print(i)
# Out:
# {'_id': ObjectId('5dd750db1af0c2fcaed8befd'), 'id': 0, 'char_id': 1, 'name': 'Aliquid iste optio reiciendi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dc1af0c2fcaed8befe'), 'id': 1, 'char_id': 2, 'name': 'Optio dolorem ex a', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dc1af0c2fcaed8beff'), 'id': 2, 'char_id': 3, 'name': 'Minus c', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dc1af0c2fcaed8bf00'), 'id': 3, 'char_id': 4, 'name': 'Sit ut repr', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dc1af0c2fcaed8bf01'), 'id': 4, 'char_id': 5, 'name': 'At id recusandae expl', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dc1af0c2fcaed8bf02'), 'id': 5, 'char_id': 6, 'name': 'Non nobis et of', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dc1af0c2fcaed8bf03'), 'id': 6, 'char_id': 7, 'name': 'Perferendis', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dd1af0c2fcaed8bf04'), 'id': 7, 'char_id': 8, 'name': 'Accusantium amet quidem eve', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dd1af0c2fcaed8bf05'), 'id': 8, 'char_id': 9, 'name': 'Sed nostrum inventore error m', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dd1af0c2fcaed8bf06'), 'id': 9, 'char_id': 10, 'name': 'Harum repellendus omnis od', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dd1af0c2fcaed8bf07'), 'id': 10, 'char_id': 11, 'name': 'Itaque ut commodi,', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dd1af0c2fcaed8bf08'), 'id': 11, 'char_id': 12, 'name': 'Molestiae quis', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dd1af0c2fcaed8bf09'), 'id': 12, 'char_id': 13, 'name': 'Ali', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750dd1af0c2fcaed8bf0a'), 'id': 13, 'char_id': 14, 'name': 'Tempora quod optio possimus il', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750de1af0c2fcaed8bf0b'), 'id': 14, 'char_id': 15, 'name': 'Sed itaque beatae pari', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750de1af0c2fcaed8bf0c'), 'id': 15, 'char_id': 16, 'name': 'Quam dolor', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750de1af0c2fcaed8bf0d'), 'id': 16, 'char_id': 17, 'name': 'Molestias expedita', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750de1af0c2fcaed8bf0e'), 'id': 17, 'char_id': 18, 'name': 'Lauda', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750de1af0c2fcaed8bf0f'), 'id': 18, 'char_id': 19, 'name': 'Incidunt sint perferen', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750de1af0c2fcaed8bf10'), 'id': 19, 'char_id': 20, 'name': 'Laboriosa', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750de1af0c2fcaed8bf11'), 'id': 20, 'char_id': 21, 'name': 'Dolore esse nesciunt fugit com', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750de1af0c2fcaed8bf12'), 'id': 21, 'char_id': 22, 'name': 'Dolorum nam reic', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750df1af0c2fcaed8bf13'), 'id': 22, 'char_id': 23, 'name': 'Repellat ad numquam volu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750df1af0c2fcaed8bf14'), 'id': 23, 'char_id': 24, 'name': 'Facere enim velit eligend', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750df1af0c2fcaed8bf15'), 'id': 24, 'char_id': 25, 'name': 'Sed ratione quis rep', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750df1af0c2fcaed8bf16'), 'id': 25, 'char_id': 26, 'name': 'Doloribus neque', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750df1af0c2fcaed8bf17'), 'id': 26, 'char_id': 27, 'name': 'Ab voluptas se', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750df1af0c2fcaed8bf18'), 'id': 27, 'char_id': 28, 'name': 'Molestias m', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750df1af0c2fcaed8bf19'), 'id': 28, 'char_id': 29, 'name': 'In pariatur corpori', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e01af0c2fcaed8bf1a'), 'id': 29, 'char_id': 30, 'name': 'Possimus ad dignissimos vel, a', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e01af0c2fcaed8bf1b'), 'id': 30, 'char_id': 31, 'name': 'At minus accusa', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e01af0c2fcaed8bf1c'), 'id': 31, 'char_id': 32, 'name': 'Ad necess', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e01af0c2fcaed8bf1d'), 'id': 32, 'char_id': 33, 'name': 'Expedita c', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e01af0c2fcaed8bf1e'), 'id': 33, 'char_id': 34, 'name': 'Voluptates sunt voluptas volu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e01af0c2fcaed8bf1f'), 'id': 34, 'char_id': 35, 'name': 'Autem mollitia fuga lauda', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e01af0c2fcaed8bf20'), 'id': 35, 'char_id': 36, 'name': 'Sint quibusdam ob', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e11af0c2fcaed8bf21'), 'id': 36, 'char_id': 37, 'name': 'Rerum et o', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e11af0c2fcaed8bf22'), 'id': 37, 'char_id': 38, 'name': 'Doloribus dolore r', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e11af0c2fcaed8bf23'), 'id': 38, 'char_id': 39, 'name': 'Eaque su', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e11af0c2fcaed8bf24'), 'id': 39, 'char_id': 40, 'name': 'Vel molestias numqua', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e11af0c2fcaed8bf25'), 'id': 40, 'char_id': 41, 'name': 'Iste assumenda repellat q', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e11af0c2fcaed8bf26'), 'id': 41, 'char_id': 42, 'name': 'Animi labo', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e11af0c2fcaed8bf27'), 'id': 42, 'char_id': 43, 'name': 'Eum culpa eaque ea omn', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e11af0c2fcaed8bf28'), 'id': 43, 'char_id': 44, 'name': 'Harum provident vel quam', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e21af0c2fcaed8bf29'), 'id': 44, 'char_id': 45, 'name': 'Aspe', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e21af0c2fcaed8bf2a'), 'id': 45, 'char_id': 46, 'name': 'Nisi nequ', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e21af0c2fcaed8bf2b'), 'id': 46, 'char_id': 47, 'name': 'Quod tempora', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e21af0c2fcaed8bf2c'), 'id': 47, 'char_id': 48, 'name': 'Porro aliq', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e21af0c2fcaed8bf2d'), 'id': 48, 'char_id': 49, 'name': 'Quas', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e21af0c2fcaed8bf2e'), 'id': 49, 'char_id': 50, 'name': 'Magnam eligendi quia animi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e21af0c2fcaed8bf2f'), 'id': 50, 'char_id': 51, 'name': 'Officiis se', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e31af0c2fcaed8bf30'), 'id': 51, 'char_id': 52, 'name': 'Id assumend', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e31af0c2fcaed8bf31'), 'id': 52, 'char_id': 53, 'name': 'Voluptatibus fu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e31af0c2fcaed8bf32'), 'id': 53, 'char_id': 54, 'name': 'Odit rat', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e31af0c2fcaed8bf33'), 'id': 54, 'char_id': 55, 'name': 'Debit', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e31af0c2fcaed8bf34'), 'id': 55, 'char_id': 56, 'name': 'Cum aut quas repudia', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e31af0c2fcaed8bf35'), 'id': 56, 'char_id': 57, 'name': 'Deleniti qui quae quidem', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e31af0c2fcaed8bf36'), 'id': 57, 'char_id': 58, 'name': 'Adipisci voluptas', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e31af0c2fcaed8bf37'), 'id': 58, 'char_id': 59, 'name': 'Debitis sit ratione eos nam', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e41af0c2fcaed8bf38'), 'id': 59, 'char_id': 60, 'name': 'Esse illo molestias archi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e41af0c2fcaed8bf39'), 'id': 60, 'char_id': 61, 'name': 'Sunt at itaque voluptatum d', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e41af0c2fcaed8bf3a'), 'id': 61, 'char_id': 62, 'name': 'Est totam', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e41af0c2fcaed8bf3b'), 'id': 62, 'char_id': 63, 'name': 'Reprehenderit commodi eius', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e41af0c2fcaed8bf3c'), 'id': 63, 'char_id': 64, 'name': 'Debit', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e41af0c2fcaed8bf3d'), 'id': 64, 'char_id': 65, 'name': 'Soluta dol', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e41af0c2fcaed8bf3e'), 'id': 65, 'char_id': 66, 'name': 'Vel nesc', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e51af0c2fcaed8bf3f'), 'id': 66, 'char_id': 67, 'name': 'Ratione quia ali', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e51af0c2fcaed8bf40'), 'id': 67, 'char_id': 68, 'name': 'Rerum recusandae minima', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e51af0c2fcaed8bf41'), 'id': 68, 'char_id': 69, 'name': 'Totam natus eius fugiat volu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e51af0c2fcaed8bf42'), 'id': 69, 'char_id': 70, 'name': 'Perferendis commodi null', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e51af0c2fcaed8bf43'), 'id': 70, 'char_id': 71, 'name': 'Laudantiu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e51af0c2fcaed8bf44'), 'id': 71, 'char_id': 72, 'name': 'Voluptat', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e51af0c2fcaed8bf45'), 'id': 72, 'char_id': 73, 'name': 'Incidunt nesciun', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e61af0c2fcaed8bf46'), 'id': 73, 'char_id': 74, 'name': 'Illum amet vero', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e61af0c2fcaed8bf47'), 'id': 74, 'char_id': 75, 'name': 'Suscipit exercitationem re', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e61af0c2fcaed8bf48'), 'id': 75, 'char_id': 76, 'name': 'Quas enim error maxime nisi m', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e61af0c2fcaed8bf49'), 'id': 76, 'char_id': 77, 'name': 'Labore qu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e61af0c2fcaed8bf4a'), 'id': 77, 'char_id': 78, 'name': 'Repudiandae deleniti unde', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e61af0c2fcaed8bf4b'), 'id': 78, 'char_id': 79, 'name': 'Ut do', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e61af0c2fcaed8bf4c'), 'id': 79, 'char_id': 80, 'name': 'Quaerat esse labore q', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e61af0c2fcaed8bf4d'), 'id': 80, 'char_id': 81, 'name': 'Quidem aliq', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e71af0c2fcaed8bf4e'), 'id': 81, 'char_id': 82, 'name': 'Aperiam vitae eos dolor sed', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e71af0c2fcaed8bf4f'), 'id': 82, 'char_id': 83, 'name': 'Minus nobis porro', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e71af0c2fcaed8bf50'), 'id': 83, 'char_id': 84, 'name': 'In similique', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e71af0c2fcaed8bf51'), 'id': 84, 'char_id': 85, 'name': 'Culpa repellat unde', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e71af0c2fcaed8bf52'), 'id': 85, 'char_id': 86, 'name': 'Architecto i', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e71af0c2fcaed8bf53'), 'id': 86, 'char_id': 87, 'name': 'A sed pariatur qua', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e71af0c2fcaed8bf54'), 'id': 87, 'char_id': 88, 'name': 'Tempore assumenda aperiam', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e81af0c2fcaed8bf55'), 'id': 88, 'char_id': 89, 'name': 'Sed ullam tempora iusto co', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e81af0c2fcaed8bf56'), 'id': 89, 'char_id': 90, 'name': 'Ipsa', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e81af0c2fcaed8bf57'), 'id': 90, 'char_id': 91, 'name': 'Fugiat incidun', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e81af0c2fcaed8bf58'), 'id': 91, 'char_id': 92, 'name': 'Molestiae of', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e81af0c2fcaed8bf59'), 'id': 92, 'char_id': 93, 'name': 'Quae quisquam cons', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e81af0c2fcaed8bf5a'), 'id': 93, 'char_id': 94, 'name': 'Repellendus ea non facil', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e81af0c2fcaed8bf5b'), 'id': 94, 'char_id': 95, 'name': 'Quod non quibu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e81af0c2fcaed8bf5c'), 'id': 95, 'char_id': 96, 'name': 'Numquam velit distinctio', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e91af0c2fcaed8bf5d'), 'id': 96, 'char_id': 97, 'name': 'Necessitatibus nihil ex debi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e91af0c2fcaed8bf5e'), 'id': 97, 'char_id': 98, 'name': 'Velit tempore nemo, na', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e91af0c2fcaed8bf5f'), 'id': 98, 'char_id': 99, 'name': 'Nesciunt v', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e91af0c2fcaed8bf60'), 'id': 99, 'char_id': 100, 'name': 'Dicta enim debitis accusantiu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e91af0c2fcaed8bf61'), 'id': 100, 'char_id': 101, 'name': 'Vitae a', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e91af0c2fcaed8bf62'), 'id': 101, 'char_id': 102, 'name': 'Praesentium voluptas u', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750e91af0c2fcaed8bf63'), 'id': 102, 'char_id': 103, 'name': 'Unde ullam mollitia? Nu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ea1af0c2fcaed8bf64'), 'id': 103, 'char_id': 104, 'name': 'Neque molestias qu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ea1af0c2fcaed8bf65'), 'id': 104, 'char_id': 105, 'name': 'Officiis es', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ea1af0c2fcaed8bf66'), 'id': 105, 'char_id': 106, 'name': 'Beatae mi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ea1af0c2fcaed8bf67'), 'id': 106, 'char_id': 107, 'name': 'Mollitia nam corporis temp', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ea1af0c2fcaed8bf68'), 'id': 107, 'char_id': 108, 'name': 'Repudiandae repellat i', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ea1af0c2fcaed8bf69'), 'id': 108, 'char_id': 109, 'name': 'Laboriosam', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ea1af0c2fcaed8bf6a'), 'id': 109, 'char_id': 110, 'name': 'Nam minus amet', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750eb1af0c2fcaed8bf6b'), 'id': 110, 'char_id': 111, 'name': 'Harum quae volup', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750eb1af0c2fcaed8bf6c'), 'id': 111, 'char_id': 112, 'name': 'Impedit facere ulla', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750eb1af0c2fcaed8bf6d'), 'id': 112, 'char_id': 113, 'name': 'Enim', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750eb1af0c2fcaed8bf6e'), 'id': 113, 'char_id': 114, 'name': 'Dolore magni', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750eb1af0c2fcaed8bf6f'), 'id': 114, 'char_id': 115, 'name': 'Eaque at corpori', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750eb1af0c2fcaed8bf70'), 'id': 115, 'char_id': 116, 'name': 'Fug', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750eb1af0c2fcaed8bf71'), 'id': 116, 'char_id': 117, 'name': 'Dolorum laudanti', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750eb1af0c2fcaed8bf72'), 'id': 117, 'char_id': 118, 'name': 'Perferendis nat', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ec1af0c2fcaed8bf73'), 'id': 118, 'char_id': 119, 'name': 'Cupidi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ec1af0c2fcaed8bf74'), 'id': 119, 'char_id': 120, 'name': 'Commodi eius dicta digniss', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ec1af0c2fcaed8bf75'), 'id': 120, 'char_id': 121, 'name': 'Debitis eu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ec1af0c2fcaed8bf76'), 'id': 121, 'char_id': 122, 'name': 'Nihil repella', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ec1af0c2fcaed8bf77'), 'id': 122, 'char_id': 123, 'name': 'Rem quasi minima hic sed anim', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ec1af0c2fcaed8bf78'), 'id': 123, 'char_id': 124, 'name': 'Sed ali', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ec1af0c2fcaed8bf79'), 'id': 124, 'char_id': 125, 'name': 'Earum vol', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ed1af0c2fcaed8bf7a'), 'id': 125, 'char_id': 126, 'name': 'Inventore tempore com', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ed1af0c2fcaed8bf7b'), 'id': 126, 'char_id': 127, 'name': 'Repell', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ed1af0c2fcaed8bf7c'), 'id': 127, 'char_id': 128, 'name': 'Consequatur quis recusandae qu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ed1af0c2fcaed8bf7d'), 'id': 128, 'char_id': 129, 'name': 'Dolores ea velit mi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ed1af0c2fcaed8bf7e'), 'id': 129, 'char_id': 130, 'name': 'Atque blanditiis a aperiam', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ed1af0c2fcaed8bf7f'), 'id': 130, 'char_id': 131, 'name': 'Reprehenderit sequi iu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ed1af0c2fcaed8bf80'), 'id': 131, 'char_id': 132, 'name': 'Natus architecto eos, hic blan', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ed1af0c2fcaed8bf81'), 'id': 132, 'char_id': 133, 'name': 'Ipsa illo quas', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ee1af0c2fcaed8bf82'), 'id': 133, 'char_id': 134, 'name': 'Voluptas ali', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ee1af0c2fcaed8bf83'), 'id': 134, 'char_id': 135, 'name': 'Voluptates obcaecati quod e', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ee1af0c2fcaed8bf84'), 'id': 135, 'char_id': 136, 'name': 'Dolor adipisci a voluptate', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ee1af0c2fcaed8bf85'), 'id': 136, 'char_id': 137, 'name': 'Repellendus natus quae, n', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ee1af0c2fcaed8bf86'), 'id': 137, 'char_id': 138, 'name': 'Laudantium earum nam in dol', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ee1af0c2fcaed8bf87'), 'id': 138, 'char_id': 139, 'name': 'Molestias face', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ee1af0c2fcaed8bf88'), 'id': 139, 'char_id': 140, 'name': 'Maiores suscipit exc', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ef1af0c2fcaed8bf89'), 'id': 140, 'char_id': 141, 'name': 'Illum dolore perferen', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ef1af0c2fcaed8bf8a'), 'id': 141, 'char_id': 142, 'name': 'Explicabo recusandae ma', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ef1af0c2fcaed8bf8b'), 'id': 142, 'char_id': 143, 'name': 'Odio obcaecati hic nostrum n', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ef1af0c2fcaed8bf8c'), 'id': 143, 'char_id': 144, 'name': 'Voluptate ali', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ef1af0c2fcaed8bf8d'), 'id': 144, 'char_id': 145, 'name': 'Repudiandae vitae sapiente mol', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ef1af0c2fcaed8bf8e'), 'id': 145, 'char_id': 146, 'name': 'Ipsam cumque', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750ef1af0c2fcaed8bf8f'), 'id': 146, 'char_id': 147, 'name': 'Fugiat quos alias eos dese', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f01af0c2fcaed8bf90'), 'id': 147, 'char_id': 148, 'name': 'Eaque impe', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f01af0c2fcaed8bf91'), 'id': 148, 'char_id': 149, 'name': 'Elige', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f01af0c2fcaed8bf92'), 'id': 149, 'char_id': 150, 'name': 'Adip', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f01af0c2fcaed8bf93'), 'id': 150, 'char_id': 151, 'name': 'Fuga nemo vel mo', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f01af0c2fcaed8bf94'), 'id': 151, 'char_id': 152, 'name': 'Libero cumque impedit eveniet', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f01af0c2fcaed8bf95'), 'id': 152, 'char_id': 153, 'name': 'Odio soluta', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f01af0c2fcaed8bf96'), 'id': 153, 'char_id': 154, 'name': 'Vero nostrum duc', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f01af0c2fcaed8bf97'), 'id': 154, 'char_id': 155, 'name': 'Repellend', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f11af0c2fcaed8bf98'), 'id': 155, 'char_id': 156, 'name': 'Quod', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f11af0c2fcaed8bf99'), 'id': 156, 'char_id': 157, 'name': 'Suscipit reiciend', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f11af0c2fcaed8bf9a'), 'id': 157, 'char_id': 158, 'name': 'Voluptat', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f11af0c2fcaed8bf9b'), 'id': 158, 'char_id': 159, 'name': 'Porro dolor fuga quam', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f11af0c2fcaed8bf9c'), 'id': 159, 'char_id': 160, 'name': 'Amet quo fugit aliquam sequi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f11af0c2fcaed8bf9d'), 'id': 160, 'char_id': 161, 'name': 'Magni adipisci veritatis sit q', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f11af0c2fcaed8bf9e'), 'id': 161, 'char_id': 162, 'name': 'Debitis enim cumque cum qu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f21af0c2fcaed8bf9f'), 'id': 162, 'char_id': 163, 'name': 'Dolorem eligend', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f21af0c2fcaed8bfa0'), 'id': 163, 'char_id': 164, 'name': 'Autem lib', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f21af0c2fcaed8bfa1'), 'id': 164, 'char_id': 165, 'name': 'Saepe assumenda perferendis f', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f21af0c2fcaed8bfa2'), 'id': 165, 'char_id': 166, 'name': 'Deserunt', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f21af0c2fcaed8bfa3'), 'id': 166, 'char_id': 167, 'name': 'Provident soluta simil', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f21af0c2fcaed8bfa4'), 'id': 167, 'char_id': 168, 'name': 'In accu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f21af0c2fcaed8bfa5'), 'id': 168, 'char_id': 169, 'name': 'Inve', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f21af0c2fcaed8bfa6'), 'id': 169, 'char_id': 170, 'name': 'Placeat sapiente', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f31af0c2fcaed8bfa7'), 'id': 170, 'char_id': 171, 'name': 'Ducimus architecto ullam', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f31af0c2fcaed8bfa8'), 'id': 171, 'char_id': 172, 'name': 'Voluptate tempora rerum', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f31af0c2fcaed8bfa9'), 'id': 172, 'char_id': 173, 'name': 'Totam incidunt earum perspicia', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f31af0c2fcaed8bfaa'), 'id': 173, 'char_id': 174, 'name': 'Optio quas e', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f31af0c2fcaed8bfab'), 'id': 174, 'char_id': 175, 'name': 'Ab illum invento', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f31af0c2fcaed8bfac'), 'id': 175, 'char_id': 176, 'name': 'Repellat quis natus totam, s', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f31af0c2fcaed8bfad'), 'id': 176, 'char_id': 177, 'name': 'Est voluptate accusantium tem', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f41af0c2fcaed8bfae'), 'id': 177, 'char_id': 178, 'name': 'Beatae q', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f41af0c2fcaed8bfaf'), 'id': 178, 'char_id': 179, 'name': 'Velit', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f41af0c2fcaed8bfb0'), 'id': 179, 'char_id': 180, 'name': 'Minus nequ', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f41af0c2fcaed8bfb1'), 'id': 180, 'char_id': 181, 'name': 'Autem eos voluptates off', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f41af0c2fcaed8bfb2'), 'id': 181, 'char_id': 182, 'name': 'Vel fug', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f41af0c2fcaed8bfb3'), 'id': 182, 'char_id': 183, 'name': 'Architecto repudian', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f41af0c2fcaed8bfb4'), 'id': 183, 'char_id': 184, 'name': 'Opti', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f51af0c2fcaed8bfb5'), 'id': 184, 'char_id': 185, 'name': 'Iust', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f51af0c2fcaed8bfb6'), 'id': 185, 'char_id': 186, 'name': 'Sapiente', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f51af0c2fcaed8bfb7'), 'id': 186, 'char_id': 187, 'name': 'Officiis repellat corrupti su', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f51af0c2fcaed8bfb8'), 'id': 187, 'char_id': 188, 'name': 'Dicta et natus e', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f51af0c2fcaed8bfb9'), 'id': 188, 'char_id': 189, 'name': 'At quos', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f51af0c2fcaed8bfba'), 'id': 189, 'char_id': 190, 'name': 'Laborum ven', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f51af0c2fcaed8bfbb'), 'id': 190, 'char_id': 191, 'name': 'Exceptur', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f51af0c2fcaed8bfbc'), 'id': 191, 'char_id': 192, 'name': 'Reiciendis assumenda dolo', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f61af0c2fcaed8bfbd'), 'id': 192, 'char_id': 193, 'name': 'Poss', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f61af0c2fcaed8bfbe'), 'id': 193, 'char_id': 194, 'name': 'Acc', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f61af0c2fcaed8bfbf'), 'id': 194, 'char_id': 195, 'name': 'Placeat esse archit', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f61af0c2fcaed8bfc0'), 'id': 195, 'char_id': 196, 'name': 'Enim repellendus nihil est te', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f61af0c2fcaed8bfc1'), 'id': 196, 'char_id': 197, 'name': 'Ipsam incidunt t', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f61af0c2fcaed8bfc2'), 'id': 197, 'char_id': 198, 'name': 'Iure', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f61af0c2fcaed8bfc3'), 'id': 198, 'char_id': 199, 'name': 'Illo en', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f71af0c2fcaed8bfc4'), 'id': 199, 'char_id': 200, 'name': 'A rem ex', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f71af0c2fcaed8bfc5'), 'id': 200, 'char_id': 201, 'name': 'Officiis su', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f71af0c2fcaed8bfc6'), 'id': 201, 'char_id': 202, 'name': 'Numquam molestias', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f71af0c2fcaed8bfc7'), 'id': 202, 'char_id': 203, 'name': 'Voluptates unde', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f71af0c2fcaed8bfc8'), 'id': 203, 'char_id': 204, 'name': 'Quae praesentium vel', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f71af0c2fcaed8bfc9'), 'id': 204, 'char_id': 205, 'name': 'Quas', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f71af0c2fcaed8bfca'), 'id': 205, 'char_id': 206, 'name': 'Dolores aliquid inv', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f71af0c2fcaed8bfcb'), 'id': 206, 'char_id': 207, 'name': 'Mollitia tempore laborum eaqu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f81af0c2fcaed8bfcc'), 'id': 207, 'char_id': 208, 'name': 'Nobis voluptates fugiat quia', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f81af0c2fcaed8bfcd'), 'id': 208, 'char_id': 209, 'name': 'Similique dolorem dolore maio', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f81af0c2fcaed8bfce'), 'id': 209, 'char_id': 210, 'name': 'Sapiente', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f81af0c2fcaed8bfcf'), 'id': 210, 'char_id': 211, 'name': 'Officia nisi dolore', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f81af0c2fcaed8bfd0'), 'id': 211, 'char_id': 212, 'name': 'Distinctio', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f81af0c2fcaed8bfd1'), 'id': 212, 'char_id': 213, 'name': 'Eos quia dignissimos saepe vel', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f81af0c2fcaed8bfd2'), 'id': 213, 'char_id': 214, 'name': 'Ullam neque sint eligendi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f91af0c2fcaed8bfd3'), 'id': 214, 'char_id': 215, 'name': 'Excepturi deleniti ab a', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f91af0c2fcaed8bfd4'), 'id': 215, 'char_id': 216, 'name': 'Accusa', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f91af0c2fcaed8bfd5'), 'id': 216, 'char_id': 217, 'name': 'Reiciendis laboriosam di', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f91af0c2fcaed8bfd6'), 'id': 217, 'char_id': 218, 'name': 'Delectus ex', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f91af0c2fcaed8bfd7'), 'id': 218, 'char_id': 219, 'name': 'Pari', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f91af0c2fcaed8bfd8'), 'id': 219, 'char_id': 220, 'name': 'Veritatis velit facilis iste', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750f91af0c2fcaed8bfd9'), 'id': 220, 'char_id': 221, 'name': 'Dol', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fa1af0c2fcaed8bfda'), 'id': 221, 'char_id': 222, 'name': 'Qui iste pr', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fa1af0c2fcaed8bfdb'), 'id': 222, 'char_id': 223, 'name': 'Deleni', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fa1af0c2fcaed8bfdc'), 'id': 223, 'char_id': 224, 'name': 'Reprehenderit volu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fa1af0c2fcaed8bfdd'), 'id': 224, 'char_id': 225, 'name': 'Accusantium vitae n', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fa1af0c2fcaed8bfde'), 'id': 225, 'char_id': 226, 'name': 'Natus consequatur incidun', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fa1af0c2fcaed8bfdf'), 'id': 226, 'char_id': 227, 'name': 'Dignissimos a', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fa1af0c2fcaed8bfe0'), 'id': 227, 'char_id': 228, 'name': 'Vitae modi', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fa1af0c2fcaed8bfe1'), 'id': 228, 'char_id': 229, 'name': 'Accusantium qu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fb1af0c2fcaed8bfe2'), 'id': 229, 'char_id': 230, 'name': 'Reiciendis dignissimos ratio', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fb1af0c2fcaed8bfe3'), 'id': 230, 'char_id': 231, 'name': 'Expedita provident natus volup', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fb1af0c2fcaed8bfe4'), 'id': 231, 'char_id': 232, 'name': 'Rerum repellat voluptas c', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fb1af0c2fcaed8bfe5'), 'id': 232, 'char_id': 233, 'name': 'Maiores quos incidunt dolor', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fb1af0c2fcaed8bfe6'), 'id': 233, 'char_id': 234, 'name': 'Aper', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fb1af0c2fcaed8bfe7'), 'id': 234, 'char_id': 235, 'name': 'Nulla', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fb1af0c2fcaed8bfe8'), 'id': 235, 'char_id': 236, 'name': 'Laudantium tempora itaque', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fc1af0c2fcaed8bfe9'), 'id': 236, 'char_id': 237, 'name': 'Reprehenderit', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fc1af0c2fcaed8bfea'), 'id': 237, 'char_id': 238, 'name': 'Aliqu', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fc1af0c2fcaed8bfeb'), 'id': 238, 'char_id': 239, 'name': 'Odio harum nam mole', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fc1af0c2fcaed8bfec'), 'id': 239, 'char_id': 240, 'name': 'Arc', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fc1af0c2fcaed8bfed'), 'id': 240, 'char_id': 241, 'name': 'Reprehenderit li', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fc1af0c2fcaed8bfee'), 'id': 241, 'char_id': 242, 'name': 'Repr', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fc1af0c2fcaed8bfef'), 'id': 242, 'char_id': 243, 'name': 'Optio m', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fc1af0c2fcaed8bff0'), 'id': 243, 'char_id': 244, 'name': 'Esse odit amet rep', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# {'_id': ObjectId('5dd750fd1af0c2fcaed8bff1'), 'id': 244, 'char_id': 245, 'name': 'Provident nostrum minima', 'level': 0, 'exp': 0, 'hp': 10, 'strength': 1, 'intelligence': 1, 'dexterity': 1, 'wisdom': 1}
# ...
# {'_id': ObjectId('5dd754541af0c2fcaed8c655'), 'id': 73, 'item_id': 74, 'name': 'Quo sunt laudantium al', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754541af0c2fcaed8c656'), 'id': 74, 'item_id': 75, 'name': 'Ist', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754541af0c2fcaed8c657'), 'id': 75, 'item_id': 76, 'name': 'Voluptatem laborum dicta cum', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754541af0c2fcaed8c658'), 'id': 76, 'item_id': 77, 'name': 'Corporis obcaecati ven', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754541af0c2fcaed8c659'), 'id': 77, 'item_id': 78, 'name': 'Neque quae eum dign', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754551af0c2fcaed8c65a'), 'id': 78, 'item_id': 79, 'name': 'Dolorem quam neque, amet cum e', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754551af0c2fcaed8c65b'), 'id': 79, 'item_id': 80, 'name': 'Rem expedit', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754551af0c2fcaed8c65c'), 'id': 80, 'item_id': 81, 'name': 'Est sapiente iusto minus quam', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754551af0c2fcaed8c65d'), 'id': 81, 'item_id': 82, 'name': 'Atque laudantium dolor q', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754551af0c2fcaed8c65e'), 'id': 82, 'item_id': 83, 'name': 'Accusan', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754551af0c2fcaed8c65f'), 'id': 83, 'item_id': 84, 'name': 'Consectetur error o', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754551af0c2fcaed8c660'), 'id': 84, 'item_id': 85, 'name': 'Alias laboriosam sapiente e', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754551af0c2fcaed8c661'), 'id': 85, 'item_id': 86, 'name': 'Doloribus animi perspiciatis', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754561af0c2fcaed8c662'), 'id': 86, 'item_id': 87, 'name': 'Hic possimus qua', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754561af0c2fcaed8c663'), 'id': 87, 'item_id': 88, 'name': 'Unde quaerat tenetur', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754561af0c2fcaed8c664'), 'id': 88, 'item_id': 89, 'name': 'Facere reprehenderit v', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754561af0c2fcaed8c665'), 'id': 89, 'item_id': 90, 'name': 'Aperiam consequuntu', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754561af0c2fcaed8c666'), 'id': 90, 'item_id': 91, 'name': 'Quis expedita ip', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754561af0c2fcaed8c667'), 'id': 91, 'item_id': 92, 'name': 'Ea vel deserunt aspernat', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754561af0c2fcaed8c668'), 'id': 92, 'item_id': 93, 'name': 'Natus', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754571af0c2fcaed8c669'), 'id': 93, 'item_id': 94, 'name': 'Optio iusto laboriosam te', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754571af0c2fcaed8c66a'), 'id': 94, 'item_id': 95, 'name': 'Laborios', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754571af0c2fcaed8c66b'), 'id': 95, 'item_id': 96, 'name': 'Commodi deserunt in illo', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754571af0c2fcaed8c66c'), 'id': 96, 'item_id': 97, 'name': 'Ad numquam dicta cons', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754571af0c2fcaed8c66d'), 'id': 97, 'item_id': 98, 'name': 'Aliquid aliquam velit reru', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754571af0c2fcaed8c66e'), 'id': 98, 'item_id': 99, 'name': 'Facere q', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754571af0c2fcaed8c66f'), 'id': 99, 'item_id': 100, 'name': 'Incidunt libero assumen', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754581af0c2fcaed8c670'), 'id': 100, 'item_id': 101, 'name': 'Earum suscipit ea voluptates i', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754581af0c2fcaed8c671'), 'id': 101, 'item_id': 102, 'name': 'Sint dolorum', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754581af0c2fcaed8c672'), 'id': 102, 'item_id': 103, 'name': 'Incidunt fugiat ea, ea', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754581af0c2fcaed8c673'), 'id': 103, 'item_id': 104, 'name': 'Molestiae r', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754581af0c2fcaed8c674'), 'id': 104, 'item_id': 105, 'name': 'Voluptatem labore laboriosa', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754581af0c2fcaed8c675'), 'id': 105, 'item_id': 106, 'name': 'Et ducimus cumque aut perspic', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754581af0c2fcaed8c676'), 'id': 106, 'item_id': 107, 'name': 'Corrupti ap', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754581af0c2fcaed8c677'), 'id': 107, 'item_id': 108, 'name': 'Perferendis nesciunt quae dolo', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754591af0c2fcaed8c678'), 'id': 108, 'item_id': 109, 'name': 'Sunt doloremque recusanda', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754591af0c2fcaed8c679'), 'id': 109, 'item_id': 110, 'name': 'Deleniti similique obc', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754591af0c2fcaed8c67a'), 'id': 110, 'item_id': 111, 'name': 'Numquam tempor', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754591af0c2fcaed8c67b'), 'id': 111, 'item_id': 112, 'name': 'Quibusdam deleniti quasi provi', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754591af0c2fcaed8c67c'), 'id': 112, 'item_id': 113, 'name': 'Accusamus exercitat', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754591af0c2fcaed8c67d'), 'id': 113, 'item_id': 114, 'name': 'Error eveniet ipsum, expedi', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754591af0c2fcaed8c67e'), 'id': 114, 'item_id': 115, 'name': 'Sapiente do', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545a1af0c2fcaed8c67f'), 'id': 115, 'item_id': 116, 'name': 'Fuga necessitatibus', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545a1af0c2fcaed8c680'), 'id': 116, 'item_id': 117, 'name': 'Nam excepturi placeat asperna', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545a1af0c2fcaed8c681'), 'id': 117, 'item_id': 118, 'name': 'Dolore fugit itaq', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545a1af0c2fcaed8c682'), 'id': 118, 'item_id': 119, 'name': 'Beatae ve', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545a1af0c2fcaed8c683'), 'id': 119, 'item_id': 120, 'name': 'Blanditiis corporis exerci', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545a1af0c2fcaed8c684'), 'id': 120, 'item_id': 121, 'name': 'Nesciunt quia nobi', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545a1af0c2fcaed8c685'), 'id': 121, 'item_id': 122, 'name': 'Quisquam e', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545a1af0c2fcaed8c686'), 'id': 122, 'item_id': 123, 'name': 'Illo q', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545b1af0c2fcaed8c687'), 'id': 123, 'item_id': 124, 'name': 'Repellat voluptates ea,', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545b1af0c2fcaed8c688'), 'id': 124, 'item_id': 125, 'name': 'Labore architecto tempora d', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545b1af0c2fcaed8c689'), 'id': 125, 'item_id': 126, 'name': 'Porro impedit enim earum nam n', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545b1af0c2fcaed8c68a'), 'id': 126, 'item_id': 127, 'name': 'Evenie', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545b1af0c2fcaed8c68b'), 'id': 127, 'item_id': 128, 'name': 'Similique do', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545b1af0c2fcaed8c68c'), 'id': 128, 'item_id': 129, 'name': 'Quos voluptates at n', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545b1af0c2fcaed8c68d'), 'id': 129, 'item_id': 130, 'name': 'Neq', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545c1af0c2fcaed8c68e'), 'id': 130, 'item_id': 131, 'name': 'Neq', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545c1af0c2fcaed8c68f'), 'id': 131, 'item_id': 132, 'name': 'Optio dolore itaque', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545c1af0c2fcaed8c690'), 'id': 132, 'item_id': 133, 'name': 'Libero saepe accusantium', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545c1af0c2fcaed8c691'), 'id': 133, 'item_id': 134, 'name': 'Illum nequ', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545c1af0c2fcaed8c692'), 'id': 134, 'item_id': 135, 'name': 'Culpa accusantium fugit id', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545c1af0c2fcaed8c693'), 'id': 135, 'item_id': 136, 'name': 'Fugit pariatur vero nesciu', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545c1af0c2fcaed8c694'), 'id': 136, 'item_id': 137, 'name': 'Numqu', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545c1af0c2fcaed8c695'), 'id': 137, 'item_id': 138, 'name': 'Corrupti sit at cum', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545d1af0c2fcaed8c696'), 'id': 138, 'item_id': 139, 'name': 'Est fugit incidunt co', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545d1af0c2fcaed8c697'), 'id': 139, 'item_id': 140, 'name': 'Quos nihil quibusdam', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545d1af0c2fcaed8c698'), 'id': 140, 'item_id': 141, 'name': 'Sit quidem tempora doloribus r', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545d1af0c2fcaed8c699'), 'id': 141, 'item_id': 142, 'name': 'Amet vel distinctio mo', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545d1af0c2fcaed8c69a'), 'id': 142, 'item_id': 143, 'name': 'Illum eaque atque recusand', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545d1af0c2fcaed8c69b'), 'id': 143, 'item_id': 144, 'name': 'Dignissi', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545d1af0c2fcaed8c69c'), 'id': 144, 'item_id': 145, 'name': 'Corporis fug', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545e1af0c2fcaed8c69d'), 'id': 145, 'item_id': 146, 'name': 'Sequi nesciunt', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545e1af0c2fcaed8c69e'), 'id': 146, 'item_id': 147, 'name': 'Facere neque qu', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545e1af0c2fcaed8c69f'), 'id': 147, 'item_id': 148, 'name': 'Corporis voluptas provi', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545e1af0c2fcaed8c6a0'), 'id': 148, 'item_id': 149, 'name': 'Repella', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545e1af0c2fcaed8c6a1'), 'id': 149, 'item_id': 150, 'name': 'Culpa cumque quo vel', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545e1af0c2fcaed8c6a2'), 'id': 150, 'item_id': 151, 'name': 'Magni totam q', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545e1af0c2fcaed8c6a3'), 'id': 151, 'item_id': 152, 'name': 'Illu', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545f1af0c2fcaed8c6a4'), 'id': 152, 'item_id': 153, 'name': 'Sit quibusdam ab, enim in ex', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545f1af0c2fcaed8c6a5'), 'id': 153, 'item_id': 154, 'name': 'Consequuntur at earum d', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545f1af0c2fcaed8c6a6'), 'id': 154, 'item_id': 155, 'name': 'Voluptatum doloremque to', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545f1af0c2fcaed8c6a7'), 'id': 155, 'item_id': 156, 'name': 'Expedita nam est in l', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545f1af0c2fcaed8c6a8'), 'id': 156, 'item_id': 157, 'name': 'Repelle', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545f1af0c2fcaed8c6a9'), 'id': 157, 'item_id': 158, 'name': 'Sit numqu', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545f1af0c2fcaed8c6aa'), 'id': 158, 'item_id': 159, 'name': 'Ipsum sit praesentium cum ame', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd7545f1af0c2fcaed8c6ab'), 'id': 159, 'item_id': 160, 'name': 'Totam delectus sed fugiat o', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754601af0c2fcaed8c6ac'), 'id': 160, 'item_id': 161, 'name': 'Doloremq', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754601af0c2fcaed8c6ad'), 'id': 161, 'item_id': 162, 'name': 'Id reprehenderit ullam rat', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754601af0c2fcaed8c6ae'), 'id': 162, 'item_id': 163, 'name': 'Dignissimos dolo', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754601af0c2fcaed8c6af'), 'id': 163, 'item_id': 164, 'name': 'Inventore re', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754601af0c2fcaed8c6b0'), 'id': 164, 'item_id': 165, 'name': 'Nemo expl', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754601af0c2fcaed8c6b1'), 'id': 165, 'item_id': 166, 'name': 'Distinctio tene', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754601af0c2fcaed8c6b2'), 'id': 166, 'item_id': 167, 'name': 'Recusandae fug', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754611af0c2fcaed8c6b3'), 'id': 167, 'item_id': 168, 'name': 'Officiis illo cum acc', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754611af0c2fcaed8c6b4'), 'id': 168, 'item_id': 169, 'name': 'Repudiandae molestias be', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754611af0c2fcaed8c6b5'), 'id': 169, 'item_id': 170, 'name': 'Iure nob', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754611af0c2fcaed8c6b6'), 'id': 170, 'item_id': 171, 'name': 'Ea dolor exercitation', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754611af0c2fcaed8c6b7'), 'id': 171, 'item_id': 172, 'name': 'Omnis maxime deserunt', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754611af0c2fcaed8c6b8'), 'id': 172, 'item_id': 173, 'name': 'Eum error eveni', 'value': 0, 'weight': 0}
# {'_id': ObjectId('5dd754611af0c2fcaed8c6b9'), 'id': 0, 'item_ptr_id': 138, 'power': 0}
# {'_id': ObjectId('5dd754611af0c2fcaed8c6ba'), 'id': 1, 'item_ptr_id': 139, 'power': 0}
# {'_id': ObjectId('5dd754621af0c2fcaed8c6bb'), 'id': 2, 'item_ptr_id': 140, 'power': 0}
# {'_id': ObjectId('5dd754621af0c2fcaed8c6bc'), 'id': 3, 'item_ptr_id': 141, 'power': 0}
# {'_id': ObjectId('5dd754621af0c2fcaed8c6bd'), 'id': 4, 'item_ptr_id': 142, 'power': 0}
# {'_id': ObjectId('5dd754621af0c2fcaed8c6be'), 'id': 5, 'item_ptr_id': 143, 'power': 0}
# {'_id': ObjectId('5dd754621af0c2fcaed8c6bf'), 'id': 6, 'item_ptr_id': 144, 'power': 0}
# {'_id': ObjectId('5dd754621af0c2fcaed8c6c0'), 'id': 7, 'item_ptr_id': 145, 'power': 0}
# {'_id': ObjectId('5dd754621af0c2fcaed8c6c1'), 'id': 8, 'item_ptr_id': 146, 'power': 0}
# {'_id': ObjectId('5dd754631af0c2fcaed8c6c2'), 'id': 9, 'item_ptr_id': 147, 'power': 0}
# {'_id': ObjectId('5dd754631af0c2fcaed8c6c3'), 'id': 10, 'item_ptr_id': 148, 'power': 0}
# {'_id': ObjectId('5dd754631af0c2fcaed8c6c4'), 'id': 11, 'item_ptr_id': 149, 'power': 0}
# {'_id': ObjectId('5dd754631af0c2fcaed8c6c5'), 'id': 12, 'item_ptr_id': 150, 'power': 0}
# {'_id': ObjectId('5dd754631af0c2fcaed8c6c6'), 'id': 13, 'item_ptr_id': 151, 'power': 0}
# {'_id': ObjectId('5dd754631af0c2fcaed8c6c7'), 'id': 14, 'item_ptr_id': 152, 'power': 0}
# {'_id': ObjectId('5dd754631af0c2fcaed8c6c8'), 'id': 15, 'item_ptr_id': 153, 'power': 0}
# {'_id': ObjectId('5dd754641af0c2fcaed8c6c9'), 'id': 16, 'item_ptr_id': 154, 'power': 0}
# {'_id': ObjectId('5dd754641af0c2fcaed8c6ca'), 'id': 17, 'item_ptr_id': 155, 'power': 0}
# {'_id': ObjectId('5dd754641af0c2fcaed8c6cb'), 'id': 18, 'item_ptr_id': 156, 'power': 0}
# {'_id': ObjectId('5dd754641af0c2fcaed8c6cc'), 'id': 19, 'item_ptr_id': 157, 'power': 0}
# {'_id': ObjectId('5dd754641af0c2fcaed8c6cd'), 'id': 20, 'item_ptr_id': 158, 'power': 0}
# {'_id': ObjectId('5dd754641af0c2fcaed8c6ce'), 'id': 21, 'item_ptr_id': 159, 'power': 0}
# {'_id': ObjectId('5dd754641af0c2fcaed8c6cf'), 'id': 22, 'item_ptr_id': 160, 'power': 0}
# {'_id': ObjectId('5dd754641af0c2fcaed8c6d0'), 'id': 23, 'item_ptr_id': 161, 'power': 0}
# {'_id': ObjectId('5dd754651af0c2fcaed8c6d1'), 'id': 24, 'item_ptr_id': 162, 'power': 0}
# {'_id': ObjectId('5dd754651af0c2fcaed8c6d2'), 'id': 25, 'item_ptr_id': 163, 'power': 0}
# {'_id': ObjectId('5dd754651af0c2fcaed8c6d3'), 'id': 26, 'item_ptr_id': 164, 'power': 0}
# {'_id': ObjectId('5dd754651af0c2fcaed8c6d4'), 'id': 27, 'item_ptr_id': 165, 'power': 0}
# {'_id': ObjectId('5dd754651af0c2fcaed8c6d5'), 'id': 28, 'item_ptr_id': 166, 'power': 0}
# {'_id': ObjectId('5dd754651af0c2fcaed8c6d6'), 'id': 29, 'item_ptr_id': 167, 'power': 0}
# {'_id': ObjectId('5dd754651af0c2fcaed8c6d7'), 'id': 30, 'item_ptr_id': 168, 'power': 0}
# {'_id': ObjectId('5dd754661af0c2fcaed8c6d8'), 'id': 31, 'item_ptr_id': 169, 'power': 0}
# {'_id': ObjectId('5dd754661af0c2fcaed8c6d9'), 'id': 32, 'item_ptr_id': 170, 'power': 0}
# {'_id': ObjectId('5dd754661af0c2fcaed8c6da'), 'id': 33, 'item_ptr_id': 171, 'power': 0}
# {'_id': ObjectId('5dd754661af0c2fcaed8c6db'), 'id': 34, 'item_ptr_id': 172, 'power': 0}
# {'_id': ObjectId('5dd754661af0c2fcaed8c6dc'), 'id': 35, 'item_ptr_id': 173, 'power': 0}
